# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/dataset lalulintas/Transportation-10-CONF-60.v2i.yolov8.zip'
extract_path = '/content/dataset'

# Ekstrak file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Ekstrak selesai!")
# Out:
# Ekstrak selesai!

# %%
# Jalankan kode ini untuk otomatis memperbaiki path di data.yaml
yaml_file = '/content/dataset/data.yaml'

with open(yaml_file, 'r') as f:
    lines = f.readlines()

with open(yaml_file, 'w') as f:
    for line in lines:
        if line.startswith('train:'):
            f.write('train: /content/dataset/train/images\n')
        elif line.startswith('val:'):
            f.write('val: /content/dataset/valid/images\n')
        elif line.startswith('test:'):
            f.write('test: /content/dataset/test/images\n')
        else:
            f.write(line)

# %%
# Uninstall ultralytics to get a clean slate for its dependencies
# !pip uninstall -y ultralytics

# Ensure a compatible numpy version is installed that works with Tensorflow/Numba
# !pip install numpy==1.26.4

# Install ultralytics. Since numpy 1.26.4 satisfies numpy>=1.23.0, pip should not upgrade numpy.
# !pip install ultralytics

from ultralytics import YOLO

# Load model nano (paling cepat)
model = YOLO('yolov8n.pt')

# Jalankan training
model.train(
    data='/content/dataset/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    device=0, # Pastikan Runtime Colab menggunakan GPU
    project='/content/drive/MyDrive/dataset lalulintas/runs', # Simpan hasil ke Drive
    name='yolov8_lalulintas'
)
# Out:
# Found existing installation: ultralytics 8.4.41
# Uninstalling ultralytics-8.4.41:
#   Successfully uninstalled ultralytics-8.4.41
# ...
#   Using cached ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
# ...
# Using cached ultralytics-8.4.41-py3-none-any.whl (1.2 MB)
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.export(format='tfjs')
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/dataset lalulintas/runs/yolov8_lalulintas/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<2.0.0', 'onnx2tf>=1.26.3,<1.29.0', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 18 packages in 5.13s
# Prepared 9 packages in 8.11s
# Installed 9 packages in 333ms
#  + ai-edge-litert==2.1.4
#  + backports-strenum==1.3.1
#  + colorama==0.4.6
#  + onnx==1.21.0
# ...
